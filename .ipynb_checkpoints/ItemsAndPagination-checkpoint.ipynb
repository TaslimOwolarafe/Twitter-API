# %%
import os, tweepy, dotenv, csv
import webbrowser
import dotenv
import pandas as pd

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
api_key = os.getenv('api_key')
api_key_secret = os.getenv("api_key_secret")
access_token = os.getenv('access_token')
access_token_secret = os.getenv("access_token_secret")
bearer_token = os.getenv("bearer_token")
client_ID = os.getenv("client_ID")
client_secret = os.getenv("cleint_secret")

# %%
callback_uri = 'oob'
print(api_key, api_key_secret)
auth = tweepy.OAuthHandler(api_key, api_key_secret, callback=callback_uri)
# Out:
# rLuK7pwhYFIO17Ji8KcbJmGRU sHJHnZJ2KH7cez7S8YJjYBZpgpGcKFetZw1oMXLxCzygdjMB8A

# %%
redirect_url = auth.get_authorization_url()

# %%
print(redirect_url)
webbrowser.open(redirect_url)
# Out:
# https://api.twitter.com/oauth/authorize?oauth_token=n0WKeQAAAAABgtOVAAABgxoccfA
# True

# %%
print(auth.access_token, auth.access_token_secret)
user_pin = input("What is the pin? ")
# Out:
# None None
# What is the pin? 4201964

# %%
auth.get_access_token(user_pin)
print(auth.access_token, auth.access_token_secret)
# Out:
# 1153676762552963072-e4jxlFddaZNFEjo2jHMyMrG0RbWEqy JjszJR6QUpzUZqjmskTQmSIWhOyNG8Ice9Y3c8zoyt3gP

# %%
api = tweepy.API(auth)

# %%
new_status = api.update_status("Hello world!")

# %%
print(new_status)
# Out:
# Status(_api=<tweepy.api.API object at 0x000001BE5C780FD0>, _json={'created_at': 'Wed Sep 07 10:00:10 +0000 2022', 'id': 1567452661317877763, 'id_str': '1567452661317877763', 'text': 'Hello world!', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://github.com/TaslimOwolarafe" rel="nofollow">TweetBotCatcher</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1153676762552963072, 'id_str': '1153676762552963072', 'name': 'tas-sama', 'screen_name': 'tasleemm_', 'location': '7.5629° N, 4.5200° E', 'description': 'Nothing to see here yet..', 'url': 'https://t.co/sg7UjOGJt4', 'entities': {'url': {'urls': [{'url': 'https://t.co/sg7UjOGJt4', 'expanded_url': 'https://github.com/TaslimOwolarafe', 'display_url': 'github.com/TaslimOwolarafe', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': True, 'followers_count': 467, 'friends_count': 440, 'listed_count': 0, 'created_at': 'Tue Jul 23 14:42:29 +0000 2019', 'favourites_count': 10500, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 2546, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1490304022678491140/sUhnDBxH_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1490304022678491140/sUhnDBxH_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1153676762552963072/1612275236', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2022, 9, 7, 10, 0, 10, tzinfo=datetime.timezone.utc), id=1567452661317877763, id_str='1567452661317877763', text='Hello world!', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, source='TweetBotCatcher', source_url='https://github.com/TaslimOwolarafe', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x000001BE5C780FD0>, _json={'id': 1153676762552963072, 'id_str': '1153676762552963072', 'name': 'tas-sama', 'screen_name': 'tasleemm_', 'location': '7.5629° N, 4.5200° E', 'description': 'Nothing to see here yet..', 'url': 'https://t.co/sg7UjOGJt4', 'entities': {'url': {'urls': [{'url': 'https://t.co/sg7UjOGJt4', 'expanded_url': 'https://github.com/TaslimOwolarafe', 'display_url': 'github.com/TaslimOwolarafe', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': True, 'followers_count': 467, 'friends_count': 440, 'listed_count': 0, 'created_at': 'Tue Jul 23 14:42:29 +0000 2019', 'favourites_count': 10500, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 2546, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1490304022678491140/sUhnDBxH_no ...

# %%
new_status.destroy()
# Out:
# Status(_api=<tweepy.api.API object at 0x000001BE5C780FD0>, _json={'created_at': 'Wed Sep 07 10:00:10 +0000 2022', 'id': 1567452661317877763, 'id_str': '1567452661317877763', 'text': 'Hello world!', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://github.com/TaslimOwolarafe" rel="nofollow">TweetBotCatcher</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1153676762552963072, 'id_str': '1153676762552963072', 'name': 'tas-sama', 'screen_name': 'tasleemm_', 'location': '7.5629° N, 4.5200° E', 'description': 'Nothing to see here yet..', 'url': 'https://t.co/sg7UjOGJt4', 'entities': {'url': {'urls': [{'url': 'https://t.co/sg7UjOGJt4', 'expanded_url': 'https://github.com/TaslimOwolarafe', 'display_url': 'github.com/TaslimOwolarafe', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': True, 'followers_count': 467, 'friends_count': 440, 'listed_count': 0, 'created_at': 'Tue Jul 23 14:42:29 +0000 2019', 'favourites_count': 10500, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 2546, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1490304022678491140/sUhnDBxH_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1490304022678491140/sUhnDBxH_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1153676762552963072/1612275236', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2022, 9, 7, 10, 0, 10, tzinfo=datetime.timezone.utc), id=1567452661317877763, id_str='1567452661317877763', text='Hello world!', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, source='TweetBotCatcher', source_url='https://github.com/TaslimOwolarafe', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x000001BE5C780FD0>, _json={'id': 1153676762552963072, 'id_str': '1153676762552963072', 'name': 'tas-sama', 'screen_name': 'tasleemm_', 'location': '7.5629° N, 4.5200° E', 'description': 'Nothing to see here yet..', 'url': 'https://t.co/sg7UjOGJt4', 'entities': {'url': {'urls': [{'url': 'https://t.co/sg7UjOGJt4', 'expanded_url': 'https://github.com/TaslimOwolarafe', 'display_url': 'github.com/TaslimOwolarafe', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': True, 'followers_count': 467, 'friends_count': 440, 'listed_count': 0, 'created_at': 'Tue Jul 23 14:42:29 +0000 2019', 'favourites_count': 10500, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 2546, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1490304022678491140/sUhnDBxH_no ...

# %%
dir(new_status)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_api',
#  '_json',
#  'author',
#  'contributors',
#  'coordinates',
#  'created_at',
#  'destroy',
#  'entities',
#  'favorite',
#  'favorite_count',
#  'favorited',
#  'geo',
#  'id',
#  'id_str',
#  'in_reply_to_screen_name',
#  'in_reply_to_status_id',
#  'in_reply_to_status_id_str',
#  'in_reply_to_user_id',
#  'in_reply_to_user_id_str',
#  'is_quote_status',
#  'lang',
#  'parse',
#  'parse_list',
#  'place',
#  'retweet',
#  'retweet_count',
#  'retweeted',
#  'retweets',
#  'source',
#  'source_url',
#  'text',
#  'truncated',
#  'user']

# %%
dir(api)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'add_list_member',
#  'add_list_members',
#  'auth',
#  'available_trends',
#  'cache',
#  'cached_result',
#  'chunked_upload',
#  'chunked_upload_append',
#  'chunked_upload_finalize',
#  'chunked_upload_init',
#  'closest_trends',
#  'create_block',
#  'create_favorite',
#  'create_friendship',
#  'create_list',
#  'create_media_metadata',
#  'create_mute',
#  'create_saved_search',
#  'delete_direct_message',
#  'destroy_block',
#  'destroy_favorite',
#  'destroy_friendship',
#  'destroy_list',
#  'destroy_mute',
#  'destroy_saved_search',
#  'destroy_status',
#  'geo_id',
#  'get_blocked_ids',
#  'get_blocks',
#  'get_direct_message',
#  'get_direct_messages',
#  'get_favorites',
#  'get_follower_ids',
#  'get_followers',
#  'get_friend_ids',
#  'get_friends',
#  'get_friendship',
#  'get_list',
#  'get_list_member',
#  'get_list_members',
#  'get_list_memberships',
#  'get_list_ownerships',
#  'get_list_subscriber',
#  'get_list_subscribers',
#  'get_list_subscriptions',
#  'get_lists',
#  'get_media_upload_status',
#  'get_muted_ids',
#  'get_mutes',
#  'get_oembed',
#  'get_place_trends',
#  'get_profile_banner',
#  'get_retweeter_ids',
#  'get_retweets',
#  'get_retweets_of_me',
#  'get_saved_search',
#  'get_saved_searches',
#  'get_settings',
#  'get_status',
#  'get_user',
#  'home_timeline',
#  'host',
#  'incoming_friendships',
#  'indicate_direct_message_typing',
#  'last_response',
#  'list_timeline',
#  'lookup_friendships',
#  'lookup_statuses',
#  'lookup_users',
#  'mark_direct_message_read',
#  'media_upload',
#  'mentions_timeline',
#  'no_retweets_friendships',
#  'outgoing_friendships',
#  'parser',
#  'proxy',
#  'rate_limit_status',
#  'remove_list_member',
#  'remove_list_members',
#  'remove_profile_banner',
#  'report_spam',
#  'request',
#  'retry_count',
#  'retry_delay',
#  'retry_errors',
#  'retweet',
#  'reverse_geocode',
#  'search_30_day',
#  'search_full_archive',
#  'search_geo',
#  'search_tweets',
#  'search_users',
#  'send_direct_message',
#  'session',
#  'set_settings',
#  'simple_upload',
#  'subscribe_list',
#  'supported_languages',
#  'timeout',
#  'unretweet',
#  'unsubscribe_list',
#  'update_friendship',
#  'update_list',
#  'update_profile',
#  'update_profile_banner',
#  'update_profile_image',
#  'update_status',
#  'update_status_with_media',
#  'upload_host',
#  'user_agent',
#  'user_timeline',
#  'verify_credentials',
#  'wait_on_rate_limit']

# %%
my_timeline = api.home_timeline()

# %%
import json

columns = set()
allowed_types = [int, str]
tweets_data = []
# columns.add('Tweeter')
for status in my_timeline:
#     print(dict(vars(status)), "\n \n")
    status_dict = dict(vars(status))
#     print(vars(status).keys(), "\n \n")
    print(status.user.screen_name)
    keys = status_dict.keys()
    single_tweet_data = {}
    for k in keys:
        if type(status_dict[k]) in allowed_types:
            columns.add(k)
            

header_cols = list(columns)
header_cols = ['tweeter', 'author'] + header_cols
for status in my_timeline:
    status_dict = dict(vars(status))
    single_tweet_data = {'tweeter': status.user.id, 'author': status.author.screen_name}
#     single_tweet_data['Tweeter'] = status.user.screen_name
    for h in header_cols[2::]:
        try:
            single_tweet_data[h] = status_dict[h]
        except:
            single_tweet_data[h] = "NaN"
#     print(single_tweet_data)
    tweets_data.append(single_tweet_data)

tweets_data_list = [[j for j in x.values()] for x in tweets_data]
# Out:
# laoluuuu
# premierleague
# anjiee_
# _Olawale_B
# Jesu_tomiisin
# IamTimmypr
# Blackalphaman_
# jamzy_saint
# OlayinkaN0
# hamidahxo
# justcruise4
# efe_soa
# efe_soa
# ManCityzenscom
# Jesu_tomiisin
# m_Olamind
# microbialawyer
# hamidahxo
# Leemah____
# Momoreoluwaa

# %%
print(header_cols, "\n")
print(tweets_data_list)
# print(tweets_data_list)
# Out:
# ['tweeter', 'author', 'favorite_count', 'quoted_status_id', 'source_url', 'text', 'source', 'quoted_status_id_str', 'lang', 'id', 'id_str', 'retweet_count']
#
# [[1170672149616615424, 'laoluuuu', 0, 1567448512513671169, 'http://twitter.com/download/iphone', 'Boehly would pay for this and I’ll be here to enjoy every bit of it!! https://t.co/J2YI9bLgAg', 'Twitter for iPhone', '1567448512513671169', 'en', 1567452561753473025, '1567452561753473025', 0], [343627165, 'premierleague', 43, 'NaN', 'https://www.spredfast.com/', 'What a transfer window! Who are your #OnesToWatch this season? \n\nPre-order @EASPORTSFIFA Ultimate Edition by Septem… https://t.co/C8d2PWGLuz', 'Khoros Publishing', 'NaN', 'en', 1567452556481142785, '1567452556481142785', 8], [4722356716, 'anjiee_', 0, 1544692012703780865, 'http://twitter.com/download/android', 'RT @Asads_ei: FINANCIAL UPDATE FOR MENTAL HEALTH SPEAKS 4\n\nAMOUNT NEEDED : 3,000,000\n\nAMOUNT RAISED SO FAR : N679,000\n\nDAYS TO PROJECT: 4 D…', 'Twitter for Android', '1544692012703780865', 'en', 1567452311860953088, '1567452311860953088', 1], [1069424341383827462, '_Olawale_B', 0, 'NaN', 'http://twitter.com/download/iphone', 'I hope the next manager phase out some of those stupid players too.', 'Twitter for iPhone', 'NaN', 'en', 1567452286368063489, '1567452286368063489', 0], [861920125158600704, 'Jesu_tomiisin', 0, 1562075547949494272, 'http://twitter.com/download/iphone', 'I now understand this tweet cause I kept wondering why he will tweet something like this. https://t.co/KeduMYbOYX', 'Twitter for iPhone', '1562075547949494272', 'en', 1567452102800048129, '1567452102800048129', 0], [1182839944756240384, 'IamTimmypr', 0, 1567451346877513728, 'http://twitter.com/download/android', "It's so stupid and a big shame\nSimilarly thing played out with previous managers it was just obvious that the playe… https://t.co/AW0i0SVaSh", 'Twitter for Android', '1567451346877513728', 'en', 1567452088652779522, '1567452088652779522', 0], [1197933614127886336, 'Blackalphaman_', 0, 1567096230177656832, 'https://mobile.twitter.com', 'Spoke Too Soon🕊️🕊️ https://t.co/j1jqIFwQoH', 'Twitter Web App', '1567096230177656832', 'en', 1567452051042353152, '1567452051042353152', 0], [1162993739574468608, 'jamzy_saint', 0, 'NaN', 'http://twitter.com/download/iphone', 'RT @opeolu_wa: Bob the builder 😂 uncompleted building https://t.co/giWWLmTcik', 'Twitter for iPhone', 'NaN', 'en', 1567452046252548097, '1567452046252548097', 16], [1171666575084130304, 'OlayinkaN0', 0, 1567448807117307904, 'http://twitter.com/download/android', 'We about to hit  ATH\nMan was using my hermano as RWB,LWB,False9,Inverted 10\nCut that crap and play him as LW… https://t.co/RA7hYH4vek', 'Twitter for Android', '1567448807117307904', 'en', 1567452001394458624, '1567452001394458624', 0], [741922864174108672, 'hamidahxo', 1, 'NaN', 'http://twitter.com/download/iphone', 'Melvitto dropped ep😲🤯\U0001faf6🏾🤭', 'Twitter for iPhone', 'NaN', 'en', 1567451981635063810, '1567451981635063810', 0], [1263843298365579264, 'justcruise4', 0, 1567439072980869122, 'http://twitter.com/download/iphone', 'Damini 🚀🚀🚀 https://t.co/Vdf5qeRrbM', 'Twitter for iPhone', '1567439072980869122', 'in', 1567451949561270273, '1567451949561270273', 0], [1190276802243170304, 'efe_soa', 0, 1567189277162831873, 'http://twitter.com/download/android', 'RT @TheIgboWolf: Do you mean Jos River?', 'Twitter for Android', '1567189277162831873', 'en', 1567451934671474688, '1567451934671474688', 335], [1190276802243170304, 'efe_soa', 0, 'NaN', 'http://twitter.com/download/android', 'RT @Drakoniques: Being asked “can I kiss you?” or “is this okay?” in the heat of the moment is so hot. Asking for consent is sexy.', 'Twitter for Android', 'NaN', 'en', 1567451906628325376, '1567451906628325376', 9864], [1057248790200094725, 'ManCityzenscom', 3, 'NaN', 'https://www.mancityzens.com', 'Ex-City player names Man City’s biggest rival this year\nhttps://t.co/o2DtU6RzjI', 'ManCityzens.com', 'NaN', 'en', 1567451887254872064, '1567451887254872064', 0], [861920125158600704, 'Jesu_tomiisin', 2, 1354135005027590145, 'http://twitter.com/download/iphone', 'Can’t believe this is  ...

# %%
# print(tweets_data)
with open('timeline_data.csv', 'w', encoding='UTF8', newline='\n') as f:
    writer = csv.writer(f)
    writer.writerow(header_cols)
    writer.writerows(tweets_data_list)

# %%
df = pd.DataFrame(tweets_data, columns=header_cols)
df.head()
# Out:
#                tweeter         author  favorite_count     quoted_status_id  \
# 0  1170672149616615424       laoluuuu               0  1567448512513671169
# 1            343627165  premierleague              43                  NaN
# 2           4722356716        anjiee_               0  1544692012703780865
# 3  1069424341383827462     _Olawale_B               0                  NaN
# 4   861920125158600704  Jesu_tomiisin               0  1562075547949494272
#
#                             source_url  \
# 0   http://twitter.com/download/iphone
# 1           https://www.spredfast.com/
# 2  http://twitter.com/download/android
# 3   http://twitter.com/download/iphone
# 4   http://twitter.com/download/iphone
#
#                                                 text               source  \
# 0  Boehly would pay for this and I’ll be here to ...   Twitter for iPhone
# 1  What a transfer window! Who are your #OnesToWa...    Khoros Publishing
# 2  RT @Asads_ei: FINANCIAL UPDATE FOR MENTAL HEAL...  Twitter for Android
# 3  I hope the next manager phase out some of thos...   Twitter for iPhone
# 4  I now understand this tweet cause I kept wonde...   Twitter for iPhone
#
#   quoted_status_id_str lang                   id               id_str  \
# 0  1567448512513671169   en  1567452561753473025  1567452561753473025
# 1                  NaN   en  1567452556481142785  1567452556481142785
# 2  1544692012703780865   en  1567452311860953088  1567452311860953088
# 3                  NaN   en  1567452286368063489  1567452286368063489
# 4  1562075547949494272   en  1567452102800048129  1567452102800048129
#
#    retweet_count
# 0              0
# 1              8
# 2              1
# 3              0
# 4              0

# %%
def extract_timeline_as_df(timeline_list):
    columns = set()
    allowed_types = [int, str]
    tweets_data = []
    # columns.add('Tweeter')
    for status in timeline_list:
    #     print(dict(vars(status)), "\n \n")
        status_dict = dict(vars(status))
    #     print(vars(status).keys(), "\n \n")
#         print(status.user.screen_name)
        keys = status_dict.keys()
        single_tweet_data = {}
        for k in keys:
            if type(status_dict[k]) in allowed_types:
                columns.add(k)

    header_cols = list(columns)
    header_cols = ['tweeter', 'author'] + header_cols
    for status in timeline_list:
        status_dict = dict(vars(status))
        single_tweet_data = {'tweeter': status.user.id_str, 'author': status.author.screen_name}
    #     single_tweet_data['Tweeter'] = status.user.screen_name
        for h in header_cols[2::]:
            try:
                single_tweet_data[h] = status_dict[h]
            except:
                single_tweet_data[h] = "NaN"
    #     print(single_tweet_data)
        tweets_data.append(single_tweet_data)

    tweets_data_list = [[j for j in x.values()] for x in tweets_data]
    df = pd.DataFrame(tweets_data, columns=header_cols)
    return df

# %%
imanie = api.get_user(screen_name="imanie")
imanie_timeline = imanie.timeline()
df1 = extract_timeline_as_df(imanie_timeline)
df1.head()
# Out:
#      tweeter  author  favorite_count quoted_status_id  \
# 0  204132871  imanie               0              NaN
# 1  204132871  imanie               0              NaN
# 2  204132871  imanie               0              NaN
# 3  204132871  imanie               0              NaN
# 4  204132871  imanie               0              NaN
#
#                            source_url  \
# 0  http://twitter.com/download/iphone
# 1  http://twitter.com/download/iphone
# 2  http://twitter.com/download/iphone
# 3  http://twitter.com/download/iphone
# 4  http://twitter.com/download/iphone
#
#                                                 text              source lang  \
# 0       Wordle 445 4/6\n\n🟩⬛⬛🟨⬛\n🟩🟩⬛⬛⬛\n🟩🟩⬛⬛🟨\n🟩🟩🟩🟩🟩  Twitter for iPhone   en
# 1  RT @ABjnr_: Spread the word. https://t.co/nEPu...  Twitter for iPhone   en
# 2  RT @RedLightning420: Homelander beefing with a...  Twitter for iPhone   en
# 3  RT @theatclub: Having a strong community of li...  Twitter for iPhone   en
# 4  RT @King_Bolarinwa: Good morning ✨\n\nMonochro...  Twitter for iPhone   en
#
#   quoted_status_id_str                   id               id_str  \
# 0                  NaN  1567443825991319553  1567443825991319553
# 1                  NaN  1567439044937760768  1567439044937760768
# 2                  NaN  1567438994123677696  1567438994123677696
# 3                  NaN  1567425926014664704  1567425926014664704
# 4                  NaN  1567425800659427331  1567425800659427331
#
#    retweet_count
# 0              0
# 1            136
# 2           6816
# 3             15
# 4             24

# %%
SSport = api.get_user(screen_name="SuperSportTV")

# %%
SSport_tl = SSport.timeline()

# %% [markdown]
# df2 = extract_timeline_as_df(SSport_tl)
# df2.head()

# %%
df2 = extract_timeline_as_df(SSport_tl)
df2.head()
# Out:
#     tweeter        author  favorite_count                  source_url  \
# 0  29930178  SuperSportTV             325         https://twitter.com
# 1  29930178  SuperSportTV              79         https://twitter.com
# 2  29930178  SuperSportTV             100  https://studio.twitter.com
# 3  29930178  SuperSportTV             105         https://twitter.com
# 4  29930178  SuperSportTV              54         https://twitter.com
#
#                                                 text                   source  \
# 0  Chelsea has parted company with Head Coach Tho...  Twitter for Advertisers
# 1  Sadio Mané is looking to become just the fourt...  Twitter for Advertisers
# 2  𝗕𝗮𝗿𝗰𝗲𝗹𝗼𝗻𝗮 𝗸𝗲𝗲𝗽 𝗮𝗱𝗱𝗶𝗻𝗴 𝗽𝗹𝗮𝘆𝗲𝗿𝘀 👀\n\nBarcelona h...     Twitter Media Studio
# 3  We've listed every single African footballer w...  Twitter for Advertisers
# 4  📞 "My country called and I had to answer.”\n\n...  Twitter for Advertisers
#
#   lang                   id               id_str  retweet_count
# 0   en  1567443090713055234  1567443090713055234             60
# 1   en  1567442675820797953  1567442675820797953             11
# 2   en  1567435125943566338  1567435125943566338             14
# 3   en  1567422429298819073  1567422429298819073             11
# 4   en  1567407449069461505  1567407449069461505              4

# %%
status_obj = api.get_status("1567422429298819073")

# %%
status_obj.text
# Out:
# "We've listed every single African footballer who will be in action in the Champions League this season. \n\nWho will… https://t.co/CVICKCRXt0"

# %%
status_tl = SSport_tl[4]
print(status_tl.id)
print(f"{status_tl.source_url}/{status_tl.user.screen_name}/status/{status_tl.id}")
# Out:
# 1567407449069461505
# https://twitter.com/SuperSportTV/status/1567407449069461505

# %%
api.retweet(status_tl.id)
# Out:
# Status(_api=<tweepy.api.API object at 0x000001BE5C780FD0>, _json={'created_at': 'Wed Sep 07 10:00:33 +0000 2022', 'id': 1567452756520181763, 'id_str': '1567452756520181763', 'text': 'RT @SuperSportTV: 📞 "My country called and I had to answer.”\n\nBlitzboks legend Cecil Afrika opens up about his selection for this weekend\'s…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'SuperSportTV', 'name': 'SuperSport 🏆', 'id': 29930178, 'id_str': '29930178', 'indices': [3, 16]}], 'urls': []}, 'source': '<a href="https://github.com/TaslimOwolarafe" rel="nofollow">TweetBotCatcher</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1153676762552963072, 'id_str': '1153676762552963072', 'name': 'tas-sama', 'screen_name': 'tasleemm_', 'location': '7.5629° N, 4.5200° E', 'description': 'Nothing to see here yet..', 'url': 'https://t.co/sg7UjOGJt4', 'entities': {'url': {'urls': [{'url': 'https://t.co/sg7UjOGJt4', 'expanded_url': 'https://github.com/TaslimOwolarafe', 'display_url': 'github.com/TaslimOwolarafe', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': True, 'followers_count': 467, 'friends_count': 440, 'listed_count': 0, 'created_at': 'Tue Jul 23 14:42:29 +0000 2019', 'favourites_count': 10500, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 2546, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1490304022678491140/sUhnDBxH_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1490304022678491140/sUhnDBxH_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1153676762552963072/1612275236', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Wed Sep 07 07:00:31 +0000 2022', 'id': 1567407449069461505, 'id_str': '1567407449069461505', 'text': '📞 "My country called and I had to answer.”\n\nBlitzboks legend Cecil Afrika opens up about his selection for this wee… https://t.co/zbEafjBGiR', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/zbEafjBGiR', 'expanded_url': 'https://twitter.com/i/web/status/1567407449069461505', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="https://twitter.com" rel="nofollow">Twitter for Advertisers</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 29930178, 'id_str': '29930178', 'name': 'SuperSport 🏆', 'screen_name': 'SuperSportTV', 'location': 'Africa', 'description': 'Join your World of Champions for all the latest sports news & updates', 'url': 'https://t.co/c5kSsvASy3', 'entities': {'url': {'urls': [{'url': 'https://t.co/c5kSsvASy3', 'expanded_url': 'http://www.supersport.com', 'display_url': 'supersport.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 3112324, 'friends_count': 601, 'listed_count': 3548, 'created_at': 'Thu Apr 09 05:33:58 +0000 2009', 'favourites_count': 1932, 'utc_offset': None, 'time_zone': None, 'geo_enabled': Tr ...

# %%
api.create_favorite(status_tl.id)
# Out:
# Status(_api=<tweepy.api.API object at 0x000001BE5C780FD0>, _json={'created_at': 'Wed Sep 07 07:00:31 +0000 2022', 'id': 1567407449069461505, 'id_str': '1567407449069461505', 'text': '📞 "My country called and I had to answer.”\n\nBlitzboks legend Cecil Afrika opens up about his selection for this wee… https://t.co/zbEafjBGiR', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/zbEafjBGiR', 'expanded_url': 'https://twitter.com/i/web/status/1567407449069461505', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="https://twitter.com" rel="nofollow">Twitter for Advertisers</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 29930178, 'id_str': '29930178', 'name': 'SuperSport 🏆', 'screen_name': 'SuperSportTV', 'location': 'Africa', 'description': 'Join your World of Champions for all the latest sports news & updates', 'url': 'https://t.co/c5kSsvASy3', 'entities': {'url': {'urls': [{'url': 'https://t.co/c5kSsvASy3', 'expanded_url': 'http://www.supersport.com', 'display_url': 'supersport.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 3112324, 'friends_count': 601, 'listed_count': 3548, 'created_at': 'Thu Apr 09 05:33:58 +0000 2009', 'favourites_count': 1932, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 338732, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/709394411168407552/p_5OEYc0_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/709394411168407552/p_5OEYc0_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/29930178/1659966693', 'profile_link_color': '0A1667', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'E9FBFB', 'profile_text_color': 'F91A28', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 5, 'favorite_count': 55, 'favorited': True, 'retweeted': True, 'lang': 'en'}, created_at=datetime.datetime(2022, 9, 7, 7, 0, 31, tzinfo=datetime.timezone.utc), id=1567407449069461505, id_str='1567407449069461505', text='📞 "My country called and I had to answer.”\n\nBlitzboks legend Cecil Afrika opens up about his selection for this wee… https://t.co/zbEafjBGiR', truncated=True, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/zbEafjBGiR', 'expanded_url': 'https://twitter.com/i/web/status/1567407449069461505', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, source='Twitter for Advertisers', source_url='https://twitter.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x000001BE5C780FD0>, _json={'id': 29930178, 'id_str': '29930178', 'name': 'SuperSport 🏆', 'screen_name': 'SuperSportTV', 'location': 'Africa', 'description': 'Join your World of Champions for all the latest sports news & updates', 'url': 'https://t.co/c5kSsvASy3', 'entities': {'url': {'urls': [{'url': 'https://t.co/c5kSsvASy3', 'expanded_url': 'http://www.supersport.com', 'display_url': 'superspo ...

# %%
recent_mention = api.mentions_timeline()[7]

# %%
my_reply = api.update_status(status = f"@{recent_mention.user.screen_name} Hello World!",  in_reply_to_status_id =recent_mention.id)

# %%
my_reply.destroy()
# Out:
# Status(_api=<tweepy.api.API object at 0x000001D5298F71C0>, _json={'created_at': 'Wed Sep 07 09:45:07 +0000 2022', 'id': 1567448873391513603, 'id_str': '1567448873391513603', 'text': '@dav_zoid Hello World!', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'dav_zoid', 'name': 'Olatunji || Startups Designer', 'id': 1207620026251038720, 'id_str': '1207620026251038720', 'indices': [0, 9]}], 'urls': []}, 'source': '<a href="https://github.com/TaslimOwolarafe" rel="nofollow">TweetBotCatcher</a>', 'in_reply_to_status_id': 1567424715479711745, 'in_reply_to_status_id_str': '1567424715479711745', 'in_reply_to_user_id': 1207620026251038720, 'in_reply_to_user_id_str': '1207620026251038720', 'in_reply_to_screen_name': 'dav_zoid', 'user': {'id': 1153676762552963072, 'id_str': '1153676762552963072', 'name': 'tas-sama', 'screen_name': 'tasleemm_', 'location': '7.5629° N, 4.5200° E', 'description': 'Nothing to see here yet..', 'url': 'https://t.co/sg7UjOGJt4', 'entities': {'url': {'urls': [{'url': 'https://t.co/sg7UjOGJt4', 'expanded_url': 'https://github.com/TaslimOwolarafe', 'display_url': 'github.com/TaslimOwolarafe', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': True, 'followers_count': 467, 'friends_count': 440, 'listed_count': 0, 'created_at': 'Tue Jul 23 14:42:29 +0000 2019', 'favourites_count': 10500, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 2546, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1490304022678491140/sUhnDBxH_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1490304022678491140/sUhnDBxH_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1153676762552963072/1612275236', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2022, 9, 7, 9, 45, 7, tzinfo=datetime.timezone.utc), id=1567448873391513603, id_str='1567448873391513603', text='@dav_zoid Hello World!', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'dav_zoid', 'name': 'Olatunji || Startups Designer', 'id': 1207620026251038720, 'id_str': '1207620026251038720', 'indices': [0, 9]}], 'urls': []}, source='TweetBotCatcher', source_url='https://github.com/TaslimOwolarafe', in_reply_to_status_id=1567424715479711745, in_reply_to_status_id_str='1567424715479711745', in_reply_to_user_id=1207620026251038720, in_reply_to_user_id_str='1207620026251038720', in_reply_to_screen_name='dav_zoid', author=User(_api=<tweepy.api.API object at 0x000001D5298F71C0>, _json={'id': 1153676762552963072, 'id_str': '1153676762552963072', 'name': 'tas-sama', 'screen_name': 'tasleemm_', 'location': '7.5629° N, 4.5200° E', 'description': 'Nothing to see here yet..', 'url': 'https://t.co/sg7UjOGJt4', 'entities': {'url': {'urls': [{'url': 'https://t.co/sg7UjOGJt4', 'expanded_url': 'https://github.com/TaslimOwolarafe', 'display_url': 'github.com/TaslimOwolarafe', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': True, 'followers_count': 467, 'friends_count': 440, 'listed_count': 0, 'created_at': 'Tue Jul 23 14:42:29 +0000 2019', 'favourites_count': 10 ...

# %%
user = api.get_user(user_id=recent_mention.user.id)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [33], in <cell line: 1>()
# ----> 1 user = api.get_user(user_id=recent_mention.user.id)
#
# NameError: name 'recent_mention' is not defined

# %%
print(f"{user.screen_name}; followers: {user.followers_count}, following: {user.friends_count}")
# Out:
# hibatullahhh; followers: 1345, following: 1474

# %%
user_friends = user.friends()
len(user_friends)
# Out:
# 20

# %%
for friend in user_friends:
    if friend.followers_count < 1000 and friend.friends_count > 1000:
        print(friend.screen_name)
#         api.destroy_friendship(screen_name=friend.screen_name)

# %%
hiba_followers = api.get_followers(user_id=user.id)

# %%
for person in hiba_followers:
    if person.followers_count < 200 and person.friends_count > 1000:
        print(person.screen_name, person.friends_count, person.followers_count)
# Out:
# Sanusiabiodun87 1170 155

# %%
me = api.get_settings()
print(me['screen_name'])
# Out:
# tasleemm_

# %%
tl = api.home_timeline(count=40)

# %%
print(len(tl))
# Out:
# 40

# %%
for i, status in enumerate(tweepy.Cursor(api.home_timeline).items(30)):
    print(i, status.text, "\n \n")
# Out:
# 0 RT @senatoramidalla: Pov: you visit Spain &amp; Italy just to say that you visited Naboo https://t.co/vgEsoqtniF
#
#
# 1 RT @GlockRivers: central cee explaining UK slang while he freestyles is genius 🔥🔥 https://t.co/eQZHfwlxvQ
#
#
# 2 RT @Siddftbl: Shock as a manager failing to manage a big signing, who was supposed to propell us to compete, raises doubts in the squad.
#
#
# 3 RT @bellesilva: Thank you so much @TTuchelofficial  for years of partnership. You’re a giant.  Good luck in everything you do… always
#
#
# 4 RT @TweetsByUche: The girl I treated like an egg, someone fried her yesterday. 😌😌😩😩😭😭😭 https://t.co/Ju7z6cMReE
#
#
# 5 RT @Fineboytems: Your girlfriend send you nudes e dey show forwarded 🚶🏿‍♂️🚶🏿‍♂️😂
#
#
# 6 RT @THEVEGAMAN_: Wipe your tears man 🤣.
#
#
# 7 RT @mizchievouzzzz: wow 🤯 https://t.co/SOK2xEDv37
#
#
# 8 RT @CFC_Ali10: 🚨Todd Boehly arriving to Cobham after sacking Thomas Tuchel. #CFC https://t.co/pldcs7GRAi
#
#
# 9 RT @Hushabel1: As my lady, if the child is crying due to hunger and it’s time to feed the poultry birds,  Leave the baby and feed the birds…
#
#
# 10 RT @voweokpovure: Can you marry the girl you knack last?👀😂
#
#
# 11 RT @_Matth3ww__: What caused your last break up?
# Be sincere please… https://t.co/tGVaIEKdVO
#
#
# 12 RT @30BGfineboy: you clapped for them and they were quiet for you. pay attention
#
#
# 13 RT @MustaphaOlatu19: Nigerian accent is Goated🤣
#
# Several countries have said they love d Nigerian accent, then wonder why some Nigerians al…
#
#
# 14 Warm, fresh bread.
#
#
# 15 DOF incoming https://t.co/t2lWJ4ghkB https://t.co/pRWuZRZ1QT
#
#
# 16 RT @siphillipssport: I’m told Graham Potter has asked Chelsea for long-term reassurances and for them to be on board fully together with th…
#
#
# 17 RT @ItzSmithz: If you had the power, which very talented up &amp; coming artiste will you've helped blow up before the end of 2022?
#
#
# 18 RT @DavieFBA: Bella from bolt keeps giving me 20% discounts on rides like I have money to even go out😭
#
#
# 19 The preshaaaa is getting wessaaaa
#
#
# 20 Please, buy bread when you're coming.
#
#
# 21 RT @brfootball: The USWNT hadn't conceded a goal since April.
#
# Nigeria's Uchenna Kanu ended their shutout streak at 880 minutes 🤯 https://t…
#
#
# 22 RT @_Anthonytweets: Can someone please explain what's happening here 👀👀🙃🙃 https://t.co/Bi2njbCfgv
#
#
# 23 RT @RmaOzil23: They all idolise Cristiano Ronaldo 🇵🇹🏆 https://t.co/cdopC04BRK
#
#
# 24 RT @FabrizioRomano: Positive talks between Chelsea and Graham Potter. He’s expected to be appointed as new manager. 🚨🔵 #CFC
#
# Those close to…
#
#
# 25 Welcome Home Big man
# Can't wait to build with you💙
# Glad We would watch some Attacking Football at the Bridge and no… https://t.co/H9Hgk268Sy
#
#
# 26 RT @_Luceey_: Fairy no fit even come Naija , na flit go kill am 😂😂
#
#
# 27 Love is for the weak
# I'mma love you for the week then dash out
#
#
# 28 RT @Gideoomatic: They can't guard Kvaratskhelia 😭😭 https://t.co/kjmiL02Le2
#
#
# 29 Congratulations, @_ajawilson22! https://t.co/vu7BDUj3A6

# %%
other_user = "imanie"
for i, status in enumerate(tweepy.Cursor(api.user_timeline, screen_name=other_user).items(30)):
    print(i, status.text, f"http://twitter.com/{status.user.screen_name}/status/{status.id}", "\n")
# Out:
# 21 RT @HARLEMSBBYBOY: The Prophecy has been Fulfilled 🤣🤣🤣 https://t.co/QxrpPItjIZ http://twitter.com/imanie/status/1567575574301786113
#
# 22 RT @itunu_kunle: New drop alert 🚨
# I just added “UNTAMED” to my genesis collection(10/10) on @opensea
# Price: 0.03eth
# 🔗: https://t.co/T8WpH… http://twitter.com/imanie/status/1567574346524229640
#
# 23 @tiwaladeogo He looks like Korty. http://twitter.com/imanie/status/1567568333830070272
#
# 24 RT @admiral_ahmad: It has reached reached my turn. Help me share please, my car was stolen earlier today. https://t.co/dg1A5oVox7 http://twitter.com/imanie/status/1567562639844286466
#
# 25 Acting like he didn’t see the distance from the kitchen to the table. http://twitter.com/imanie/status/1567562417701363715
#
# 26 How does that look like showing off. Instead of you to suggest a trailer or cart. https://t.co/WzTTrpEYxj http://twitter.com/imanie/status/1567562411820941320
#
# 27 Which kin struggle be this one😭😂😂 https://t.co/GLM87NAtMI http://twitter.com/imanie/status/1567561861616340992
#
# 28 RT @mischiefanimals: https://t.co/5V8h4LYRUT http://twitter.com/imanie/status/1567559770923581441
#
# 29 RT @_AdewaleMayowa: If you're ever lost, my North Star will guide you home... https://t.co/gS3E5HFIRb http://twitter.com/imanie/status/1567558130686459907

# %%
new_tweet = api.update_status_with_media(status="I've been in this tunnel since the beginning of.. where the light?", filename="Demon.png")

# %%
print(new_tweet.text)
# Out:
# I've been in this tunnel since the beginning of.. where the light? https://t.co/g7tQS04yKr

# %%
myself = api.get_user(screen_name="tasleemm_")

# %%
for i, user_id in enumerate(tweepy.Cursor(api.get_friend_ids, screen_name="tasleemm_").items(1000)):
    print(i+1, user_id)
# Out:
# 1 1377676308075925505
# 2 169686021
# 3 1298879333801500678
# 4 136107849
# 5 866953267
# 6 1510843292719759360
# 7 1551230591613472770
# 8 1300509279527542790
# 9 1525315617611554818
# 10 1276114960310054912
# 11 814189493867540481
# 12 1084774505745207301
# 13 1259087765955842048
# 14 1166276069688827906
# 15 406574362
# 16 92849457
# 17 811086947003355136
# 18 8018332
# 19 994973367265525760
# 20 1531754459436568576
# 21 1450779366133227523
# 22 1207620026251038720
# 23 892364117427802112
# 24 1064440030561804288
# 25 2279776304
# 26 1179217480151121922
# 27 1328704176772288513
# 28 1186020970328444929
# 29 24897626
# 30 1303598789547225090
# 31 754006735468261376
# 32 773998101631791105
# 33 925874058125828096
# 34 935941773066719232
# 35 3165563219
# 36 2557521
# 37 1180467227314835456
# 38 215052012
# 39 301988901
# 40 1069424341383827462
# 41 1286087376914329601
# 42 762799939395158016
# 43 1477260704306638849
# 44 308422682
# 45 1350999982615244801
# 46 1361817619628756995
# 47 1429847344636379139
# 48 23561980
# 49 629879474
# 50 1043545653136244736
# 51 1065682660952027137
# 52 1209130019840233473
# 53 1162993739574468608
# 54 1100507919303495680
# 55 1218587292585144321
# 56 859280289654341636
# 57 1388176215962492931
# 58 1080098631817007104
# 59 1162288200523702272
# 60 210754750
# 61 1320753596
# 62 1141764562540277760
# 63 962720226319183872
# 64 785893402386784256
# 65 1327853780566740992
# 66 1370815067860652032
# 346 1178751449507024900
# 347 969266093947801602
# 348 908995343219658752
# 349 19923144
# 350 204132871
# 351 1213799200514666498
# 352 1213837757845397505
# 353 1042218162
# 354 26216972
# 355 2490420633
# 356 1022595603040231425
# 357 4748303717
# 358 1218520339891834880
# 359 1247314158342877187
# 360 3473511741
# 361 1032743637422096387
# 362 1232709956857712647
# 363 1198496684
# 364 1241468930918682625
# 365 1234169648092008450
# 366 976199419463983105
# 367 1079806625442119680
# 368 1149584226154471424
# 369 1171666575084130304
# 370 1217405591611695105
# 371 1213603493656711168
# 372 1046314144557936640
# 373 811228391009583104
# 374 815136566565892096
# 375 88212427
# 376 958990412248645634
# 377 923511611465269248
# 378 590323236
# 379 1126997930680963072
# 380 996419493214720001
# 381 900823581482942472
# 382 937367409614311424
# 383 1033832755493257217
# 384 1168286877176213506
# 385 1183016994
# 386 2829932277
# 387 312209804
# 388 3186354236
# 389 753515670344720392
# 390 1197117496941264896
# 391 1214406797966168066
# 392 1215767296251133953
# 393 968873107749507072
# 394 1085035711705735168
# 395 1057248790200094725
# 396 247653244
# 397 1169642534672510976
# 398 4783206301
# 399 1032709034707771392
# 400 289244424
# 401 1165284631031242757
# 402 1064925463234121728
# 403 1088726825277247488
# 404 1091728677019287552
# 405 21247989
# 406 921856548258885636
# 407 1095076611035148289
# 408 14573900
# 409 1192438006390697984
# 410 1561123663
# 411 262096134
# 412 1191140153701650432
# 413 1175934089960071168
# 414 1852644804
# 415 343627165
# 416 18222378
# 417 23497233
# 418 22940219
# 419 1149028528941359104
# 420 975325226119630848
# 421 976891976300851200
# 422 4693405273
# 423 753215592581201920
# 424 2931749429
# 425 1690689024
# 426 1027242411414769664
# 427 980576634913861634
# 428 1053264407336284160
# 429 1053231242366332929
# 430 461922813
# 431 1160296090110963712
# 432 732017421612142592
# 433 29930178
# 434 1158053891226984449
# 435 268720183
# 436 1675048088
# 437 710425792363237377
# 438 1038559794221776896

# %%
client = client = tweepy.Client(bearer_token=bearer_token, consumer_key=api_key,
                      consumer_secret=api_key_secret,
                      access_token=access_token, access_token_secret=access_token_secret,
                      return_type='Response', wait_on_rate_limit=False)

# %%
print(client.session)
# Out:
# <requests.sessions.Session object at 0x000002A52B95AC20>

# %%
query = "#BAT"
for i, status in enumerate(tweepy.cursor(client.search_recent_tweets(query=query)).items(50)):
    print(i, status, status.author.screen_name, "\n")
# Out:
# ------------------------------------------------
# TypeError      Traceback (most recent call last)
# Input In [57], in <cell line: 2>()
#       1 query = "#BAT"
# ----> 2 for i, status in enumerate(tweepy.cursor(client.search_recent_tweets(query=query)).items(50)):
#       3     print(i, status, status.author.screen_name, "\n")
#
# TypeError: 'module' object is not callable

# %%
possible_tweets = client.search_recent_tweets(query="#BAT",max_results=80)
# print(len(possible_tweets.data))
for tweet in possible_tweets.data:
    print(tweet, "\n")
# Out:
# Swing 🚥 Signals
#
# #SNX 🟡 $3.00
# #KLAY 🔴 $0.22
# #FTM 🟡 $0.26
# #NEO 🟡 $8.89
# #RUNE 🟡 $1.85
# #CRV 🟡 $1.18
# #HNT 🟢 $5.23
# #ENJ 🟡 $0.52
# #BAT 🔴 $0.33
# #DASH 🟡 $45.28
#
# https://t.co/xzqH6LyCnS
#
# #BAT
# Fiyat : $ 0.3269
# Direnç : $ 0.3954
# Destek : $ 0.2867
#
# Binance borsasında listelenen diğer kripto para birimlerinin destek ve direnç seviyelerine https://t.co/zGauPSghWk dan ulaşabilirsiniz.
#
# Telegram kanalımıza davetlisiniz. https://t.co/ISRIObsQSh https://t.co/KcCp8NZ2NB
#
# RT @hotinhoustonnow: #NATURELOVERS ALERT--@HoustonArboretu  has the #BAT FEST coming soon! Get details here: https://t.co/xgEA0FrpAe https:…
#
# Love that #Brave lets me support creators! Just tipped https://t.co/zI0LLBYa8m with #BAT. If they verify at https://t.co/72U69U3ish before Dec 6, 2022, the BAT is theirs! #TipWithBrave
#
# 3D Jack O'Lantern with Bat and Spider, Layered Art, Halloween Decor
#  #Halloween #art #Layered #bat #Spider #decor #JackOlantern #CreationsbyCasady
#
# 👉https://t.co/Iqy7QXR3zh https://t.co/QhbCfyld2a
#
# RT @FawaShah: Morning #EarlyBiz I make and sell jewellery just like this NEW pair of spooky bat earrings https://t.co/gRp1eovLZl #Halloween…
#
# 🚄 #ETC and 51 Others,  🟢 39 🔴 13
#
# 🇰🇷 40.13억원
# 🇺🇸 $3,433,871
# 🇯🇵 ¥377,170,724
# 🇪🇺 €2,906,356
# 🇨🇳 22,168,129元
#
# 🎉Upflow volume Now, Upbit(Korea)
# #ETC #ETH #BTC #FLOW #ADA #SOL #EOS #MATIC #MFT #SXP #NEO #PLA #HUNT #KNC #BCH #FCT2 #DKA #STPT #TFUEL #BAT #AAVE #CHZ #AVAX #AQ https://t.co/tPwAwU8Uw4
#
# 🚄 #ETC and 48 Others,  🟢 33 🔴 16
#
# 🇰🇷 40.19억원
# 🇺🇸 $3,439,064
# 🇯🇵 ¥377,741,136
# 🇪🇺 €2,910,751
# 🇨🇳 22,201,655元
#
# 🎉Upflow volume Now, Upbit(Korea)
# #ETC #ETH #BTC #FLOW #SOL #ADA #ALGO #MFT #SXP #HUNT #NEO #PLA #KNC #BCH #FCT2 #DKA #STPT #BAT #AAVE #AVAX #AQT #LINK #BORA #GMT https://t.co/K6Y9KEIvR7
#
# 🚄 #XRP and 43 Others,  🟢 29 🔴 15
#
# 🇰🇷 31.79억원
# 🇺🇸 $2,720,743
# 🇯🇵 ¥298,842,017
# 🇪🇺 €2,302,780
# 🇨🇳 17,564,376元
#
# 🎉Upflow volume Now, Upbit(Korea)
# #XRP #BTC #ETH #ETC #ALGO #ADA #FLOW #EOS #AERGO #CELO #MANA #BORA #HUNT #MFT #SOL #SXP #CHZ #AVAX #AQT #DOGE #LOOM #BAT #ARK #S https://t.co/HhXYH54cYY
#
# #NATURELOVERS ALERT--@HoustonArboretu  has the #BAT FEST coming soon! Get details here: https://t.co/xgEA0FrpAe https://t.co/FHBlVLZ1VK
#
# 🚄 #BTC and 46 Others,  🟢 22 🔴 25
#
# 🇰🇷 46.45억원
# 🇺🇸 $3,974,790
# 🇯🇵 ¥436,584,359
# 🇪🇺 €3,364,178
# 🇨🇳 25,660,153元
#
# 🎉Upflow volume Now, Upbit(Korea)
# #BTC #XRP #ETH #ETC #EOS #FLOW #RFR #AERGO #SRM #HUNT #STPT #VET #LOOM #BORA #STRAX #AQT #ARK #BAT #QTUM #MVL #STX #GLM https://t.co/u5dJ2EkcN8
#
# RT @JeiArrShi: Hey, guys! I’m making my (lil but) grand debut as Komori-chan on #Twitch rn! Imma be showing off my new #pngtuber model and…
#
# don't act upon it unless you know what you're doing
# $BAT: Something is happening with BAT-USDT #BAT
# ratio ~ 0.72
# mc / vol. ratio 0.07
# kc vol ~ 1.12
# MC 472792602.0
# (re)enter @ 0.31726
#
# Hey, guys! I’m making my (lil but) grand debut as Komori-chan on #Twitch rn! Imma be showing off my new #pngtuber model and then play some #SmashBros &amp; #Splatoon. Come watch if you wanna see this lil #bat #furry become #TwitchAffliate soon :3
#
# https://t.co/2NsEHBXJcT
#
# RT @MOJO_HARDBALL: 2022 Permian Baseball B.A.T. Award #4 goes to SOPHOMORE RHP/INF #30, CAL WARREN!! @warren_callan
# #WE/me #1+1=3 #P.R.I.D…
#
# ‘Batman Azteca’ Reveals First Look at Joker &amp; the Mexican Actor Voicing Batman - Remezcla https://t.co/tccQKtNsIP #batman #warnerbros #dccomics #fumetti #comics #catwoman #robin #damianwayne #batmobile #paninicomics #joker #harleyquinn #brucewayne #thedarkknight #DCFanDome #Bat…
#
# #BATUSDT Bull Alert!5X VolumePrice:      0.3475-min %: 0.029%Volume:  $27,960 #crypto #whale #btc #eth #BAT… https://t.co/3Q7GsqWSJY
#
# #BAT Price Prediction 2022-2031: Is #BAT a Good Investment?
#
# https://t.co/FnxszJ0Nvc
#
# RT @MOJO_HARDBALL: 2022 Permian Baseball B.A.T. Award #4 goes to SOPHOMORE RHP/INF #30, CAL WARREN!! @warren_callan
# #WE/me #1+1=3 #P.R.I.D…
#
# 3D Jack O'Lantern with Bat and Spider, Layered Art, Halloween Decor
#  #JackOlantern #Layered #art #Spider #decor #bat #Halloween #CreationsbyCasady
# https://t.co/mZeITw3fRo
#
# RT @YariTheImpaler: 🦇Howdy!  Streaming: Made in Abyss: Binary Star Falling into Darkness!; @ 4:00 PT.   Come check it out!  https://t.co/cY…
#
# RT @FawaShah: Morning #EarlyBiz I make and sell jewellery just like this NEW pair of spooky bat earrings https://t.co/gRp1eovLZl #Halloween…
#
# RT https://t.co/vPZZYU0HXi RT https://t.co/DbwOAhGbwd 6 Great Ideas for Bathroom Organization and Storage… VIEW IDEAS... https://t.co/daT85B2WLe #bathroomorganization #bathroomdesign #bat… https://t.co/ReGgIMD7GW
#
# RT @FadaunsiAdeniyi: The way #BAT is campaigning about how he transformed Lagos State one would think the whole of Lagos has the same ambie…
#
# RT @FadaunsiAdeniyi: The way #BAT is campaigning about how he transformed Lagos State one would think the whole of Lagos has the same ambie…
#
# Swing 🚥 Signals
#
# #SNX 🟡 $3.00
# #KLAY 🔴 $0.22
# #FTM 🟡 $0.26
# #NEO 🟡 $8.89
# #RUNE 🟡 $1.84
# #CRV 🟡 $1.16
# #HNT 🟢 $5.13
# #ENJ 🟡 $0.52
# #BAT 🔴 $0.33
# #DASH 🟡 $45.21
#
# https://t.co/xzqH6LyCnS
#
# RT @FadaunsiAdeniyi: The way #BAT is campaigning about how he transformed Lagos State one would think the whole of Lagos has the same ambie…
#
# RT @FadaunsiAdeniyi: The way #BAT is campaigning about how he transformed Lagos State one would think the whole of Lagos has the same ambie…
#
# Had a brilliant trip to pooles cavern, and saw a #bat roost (see the poo?). The cave is home to Soprano pipistrelles, Serotines, and Daubentons bats. It stays at 7°c year round.
#
# #geology #caves #mammals #minerals https://t.co/rcs4TivZsl
#
# RT @efstuber: Post-MS Research position on #bat distributions and trends in UT w/@USU_WILD &amp; @USGSCoopUnits  available soon!
#
# Short-term (u…
#
# RT @FadaunsiAdeniyi: The way #BAT is campaigning about how he transformed Lagos State one would think the whole of Lagos has the same ambie…
#
# More then one way to show support to @TheDAMshow_   Love that #Brave lets me support creators! Just tipped The DAM Show with #BAT. If they verify at https://t.co/1KnVgjRpeM before Dec 6, 2022, the BAT is theirs! #TipWithBrave
#
# RT @FadaunsiAdeniyi: The way #BAT is campaigning about how he transformed Lagos State one would think the whole of Lagos has the same ambie…
#
# RT @FadaunsiAdeniyi: The way #BAT is campaigning about how he transformed Lagos State one would think the whole of Lagos has the same ambie…
#
# RT @FadaunsiAdeniyi: The way #BAT is campaigning about how he transformed Lagos State one would think the whole of Lagos has the same ambie…
#
# #BAT
# Fiyat : $ 0.3281
# Direnç : $ 0.3954
# Destek : $ 0.2867
#
# Binance borsasında listelenen diğer kripto para birimlerinin destek ve direnç seviyelerine https://t.co/AeLqSITPj1 dan ulaşabilirsiniz.
#
# Telegram kanalımıza davetlisiniz. https://t.co/DILn0JvJUZ https://t.co/W5VE5LTZFw
#
# Update:10%profit
# #ETC #ETH #ATOM #ZIL #ADA #BTG #SBD #SOL #SAND #SXP #1INCH #IOST #XEM #STORJ #DOGE #MTL #SNT #BAT #TFUEL #CRO #STX #STRAX #FLOW #nfts https://t.co/DgYxBwxTsj
#
# RT @VerityScoop: PART 3
# ...enter Seyi Tinubu! EMONEY!😏... more reciepts!
# #gistlovers
# #gistloversblog
# #emoney
# #seyitinubu
# #BAT https://t.co…
#
# 🚄 #ETC and 52 Others,  🟢 25 🔴 28
#
# 🇰🇷 43.8억원
# 🇺🇸 $3,748,416
# 🇯🇵 ¥411,719,838
# 🇪🇺 €3,172,580
# 🇨🇳 24,198,746元
#
# 🎉Upflow volume Now, Upbit(Korea)
# #ETC #XRP #ETH #STMX #BTC #KNC #BTG #SOL #AAVE #BCH #ZIL #XLM #QKC #ATOM #REP #CBK #ONG #TT #PUNDIX #STRAX #LINK #IQ #ARK #BAT #S https://t.co/WUpmCMkp9r
#
# RT @chikemefu: Who is even claiming that #BAT built Lagos, Lagos was former Nigerian Capital. If #BAT is that wonderful why didn't he go an…
#
# RT @Melrakki_Berry: Cuddles with my cute bean. ❤️
# 🇺🇸 $3,388,645
# 🇯🇵 ¥372,203,186
# 🇪🇺 €2,868,077
# 🇨🇳 21,876,163元
#
# 🎉Upflow volume Now, Upbit(Korea)
# #EOS #ETC #1INCH #KNC #ETH #MATIC #SOL #DOGE #AAVE #ALGO #THETA #BTG #XRP #BCH #QKC #XTZ #MFT #GLM #AERGO #OMG #QTUM #BAT #ANKR #C https://t.co/3c2u2DM4te
#
# 🚄 #EOS and 51 Others,  🟢 48 🔴 4
#
# 🇰🇷 32.95억원
# 🇺🇸 $2,819,680
# 🇯🇵 ¥309,709,016
# 🇪🇺 €2,386,517
# 🇨🇳 18,203,081元
#
# 🎉Upflow volume Now, Upbit(Korea)
# #EOS #ETC #1INCH #SOL #KNC #ALGO #ETH #BTC #MATIC #ADA #AAVE #BTG #THETA #BCH #XTZ #MFT #DOGE #MVL #AERGO #BAT #OMG #QTUM #SXP #A https://t.co/sDmzA0aNmX
#
# If you're an hustler outside Lagos, and aspiring to come to Lagos for the big win; you don't have to worry too much.
# With #BAT presidency, Lagos is coming to you.
# #BAT2023
#
# 70%profit
# Follow me
# #BTC #bnb #ETH #etc #NFTs #ETC #ETH #ATOM #ZIL #ADA #BTG #SBD #SOL #SAND #SXP #1INCH #IOST #XEM #STORJ #DOGE #MTL #SNT #BAT #TFUEL #CRO #STX #STRAX #FLOW https://t.co/94RsTpKfJa https://t.co/0a1bm90vRB
#
# #BATUSDT #BAT
# Signal #1
#
# Last Signal: N/A
# Before: 0.31420000
# After: 0.32750000 🟢(4.23%)
# Volume Chng: 132,774 USDT (5.71%)
#
# Daily
# Price Chng: (4.23%)🟢
# Volume: 1,901,411 USDT
#
# 🚀PRO ➡️ https://t.co/1EgdzYf2ot 🐳
#
# #Crypto #Bitcoin #BTC #ETH
#
# #BATUSDT Bull Alert!
#
# 20X Volume
# Price:      0.3274
# 5-min %: 0.46%
# Volume:  $132,843
#
# #crypto #whale #btc #eth #BAT $BAT https://t.co/ljI1YVyBmc
#
# #BATUSDT Bull Alert!
#
# 15X Volume
# Price:      0.3282
# 5-min %: 0.71%
# Volume:  $102,456
#
# #crypto #whale #btc #eth #BAT $BAT https://t.co/wFr2c81p52
#
# #BATUSDT Bull Alert!
#
# 10X Volume
# Price:      0.3273
# 5-min %: 0.43%
# Volume:  $69,588
#
# #crypto #whale #btc #eth #BAT $BAT https://t.co/blsEUpPh4W
#
# #BATUSDT Bull Alert!
#
# 5X Volume
# Price:      0.3271
# 5-min %: 0.37%
# Volume:  $36,382
#
# #crypto #whale #btc #eth #BAT $BAT https://t.co/fmUAfsYwFl
#
# 🚨 Signal Alert 🚨 #Bybit Futures: #BAT ($BATUSDT) | Side: Short 🔻, Signal Strength: 58%, Entry price: $0.3250, TP: $0.2954, SL: $0.3316, Volatility: 0.24% | 👁️  More: https://t.co/fgX7gcjSnt https://t.co/rHxFvb2acL
#
# Increase in Trades
# BATUSDT, has 591% increase in the number of trades going through
# Previous total trades: 34
# Current total trades: 201
# Average trades: 53
# Market price: 0.3259
# Buyers: 58%
# Sellers: 42%
