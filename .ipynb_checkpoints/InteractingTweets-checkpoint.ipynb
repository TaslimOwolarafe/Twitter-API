# %%
import os, tweepy, dotenv, csv
import webbrowser
import dotenv
import pandas as pd

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
api_key = os.getenv('api_key')
api_key_secret = os.getenv("api_key_secret")
access_token = os.getenv('access_token')
access_token_secret = os.getenv("access_token_secret")

# %%
callback_uri = 'oob'
auth = tweepy.OAuthHandler(api_key, api_key_secret, callback=callback_uri)

# %%
redirect_url = auth.get_authorization_url()

# %%
print(redirect_url)
webbrowser.open(redirect_url)
# Out:
# https://api.twitter.com/oauth/authorize?oauth_token=bUYybgAAAAABgtOVAAABgxGX8xA
# True

# %%
print(auth.access_token, auth.access_token_secret)
user_pin = input("What is the pin? ")
# Out:
# None None
# What is the pin? 1540102

# %%
auth.get_access_token(user_pin)
print(auth.access_token, auth.access_token_secret)
# Out:
# 1153676762552963072-aTA5t5pd14XMlh7I6YI3hfTytQ0Xho yeZzUQQWinX2qocA0mTwLsIXlLxuGhS6hsTsZLC4Gmdo8

# %%
api = tweepy.API(auth)

# %%
new_status = api.update_status("Hello world!")

# %%
print(new_status)
# Out:
# Status(_api=<tweepy.api.API object at 0x000002ADB8311B10>, _json={'created_at': 'Tue Sep 06 09:06:57 +0000 2022', 'id': 1567076877117833216, 'id_str': '1567076877117833216', 'text': 'Hello world!', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://github.com/TaslimOwolarafe" rel="nofollow">TweetBotCatcher</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1153676762552963072, 'id_str': '1153676762552963072', 'name': 'tas-sama', 'screen_name': 'tasleemm_', 'location': '7.5629° N, 4.5200° E', 'description': 'Nothing to see here yet..', 'url': 'https://t.co/sg7UjOGJt4', 'entities': {'url': {'urls': [{'url': 'https://t.co/sg7UjOGJt4', 'expanded_url': 'https://github.com/TaslimOwolarafe', 'display_url': 'github.com/TaslimOwolarafe', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': True, 'followers_count': 467, 'friends_count': 440, 'listed_count': 0, 'created_at': 'Tue Jul 23 14:42:29 +0000 2019', 'favourites_count': 10498, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 2540, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1490304022678491140/sUhnDBxH_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1490304022678491140/sUhnDBxH_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1153676762552963072/1612275236', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2022, 9, 6, 9, 6, 57, tzinfo=datetime.timezone.utc), id=1567076877117833216, id_str='1567076877117833216', text='Hello world!', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, source='TweetBotCatcher', source_url='https://github.com/TaslimOwolarafe', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x000002ADB8311B10>, _json={'id': 1153676762552963072, 'id_str': '1153676762552963072', 'name': 'tas-sama', 'screen_name': 'tasleemm_', 'location': '7.5629° N, 4.5200° E', 'description': 'Nothing to see here yet..', 'url': 'https://t.co/sg7UjOGJt4', 'entities': {'url': {'urls': [{'url': 'https://t.co/sg7UjOGJt4', 'expanded_url': 'https://github.com/TaslimOwolarafe', 'display_url': 'github.com/TaslimOwolarafe', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': True, 'followers_count': 467, 'friends_count': 440, 'listed_count': 0, 'created_at': 'Tue Jul 23 14:42:29 +0000 2019', 'favourites_count': 10498, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 2540, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1490304022678491140/sUhnDBxH_nor ...

# %%
new_status.destroy()
# Out:
# Status(_api=<tweepy.api.API object at 0x000002ADB8311B10>, _json={'created_at': 'Tue Sep 06 09:06:57 +0000 2022', 'id': 1567076877117833216, 'id_str': '1567076877117833216', 'text': 'Hello world!', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://github.com/TaslimOwolarafe" rel="nofollow">TweetBotCatcher</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1153676762552963072, 'id_str': '1153676762552963072', 'name': 'tas-sama', 'screen_name': 'tasleemm_', 'location': '7.5629° N, 4.5200° E', 'description': 'Nothing to see here yet..', 'url': 'https://t.co/sg7UjOGJt4', 'entities': {'url': {'urls': [{'url': 'https://t.co/sg7UjOGJt4', 'expanded_url': 'https://github.com/TaslimOwolarafe', 'display_url': 'github.com/TaslimOwolarafe', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': True, 'followers_count': 467, 'friends_count': 440, 'listed_count': 0, 'created_at': 'Tue Jul 23 14:42:29 +0000 2019', 'favourites_count': 10498, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 2540, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1490304022678491140/sUhnDBxH_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1490304022678491140/sUhnDBxH_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1153676762552963072/1612275236', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2022, 9, 6, 9, 6, 57, tzinfo=datetime.timezone.utc), id=1567076877117833216, id_str='1567076877117833216', text='Hello world!', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, source='TweetBotCatcher', source_url='https://github.com/TaslimOwolarafe', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x000002ADB8311B10>, _json={'id': 1153676762552963072, 'id_str': '1153676762552963072', 'name': 'tas-sama', 'screen_name': 'tasleemm_', 'location': '7.5629° N, 4.5200° E', 'description': 'Nothing to see here yet..', 'url': 'https://t.co/sg7UjOGJt4', 'entities': {'url': {'urls': [{'url': 'https://t.co/sg7UjOGJt4', 'expanded_url': 'https://github.com/TaslimOwolarafe', 'display_url': 'github.com/TaslimOwolarafe', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': True, 'followers_count': 467, 'friends_count': 440, 'listed_count': 0, 'created_at': 'Tue Jul 23 14:42:29 +0000 2019', 'favourites_count': 10498, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 2540, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1490304022678491140/sUhnDBxH_nor ...

# %%
dir(new_status)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_api',
#  '_json',
#  'author',
#  'contributors',
#  'coordinates',
#  'created_at',
#  'destroy',
#  'entities',
#  'favorite',
#  'favorite_count',
#  'favorited',
#  'geo',
#  'id',
#  'id_str',
#  'in_reply_to_screen_name',
#  'in_reply_to_status_id',
#  'in_reply_to_status_id_str',
#  'in_reply_to_user_id',
#  'in_reply_to_user_id_str',
#  'is_quote_status',
#  'lang',
#  'parse',
#  'parse_list',
#  'place',
#  'retweet',
#  'retweet_count',
#  'retweeted',
#  'retweets',
#  'source',
#  'source_url',
#  'text',
#  'truncated',
#  'user']

# %%
dir(api)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'add_list_member',
#  'add_list_members',
#  'auth',
#  'available_trends',
#  'cache',
#  'cached_result',
#  'chunked_upload',
#  'chunked_upload_append',
#  'chunked_upload_finalize',
#  'chunked_upload_init',
#  'closest_trends',
#  'create_block',
#  'create_favorite',
#  'create_friendship',
#  'create_list',
#  'create_media_metadata',
#  'create_mute',
#  'create_saved_search',
#  'delete_direct_message',
#  'destroy_block',
#  'destroy_favorite',
#  'destroy_friendship',
#  'destroy_list',
#  'destroy_mute',
#  'destroy_saved_search',
#  'destroy_status',
#  'geo_id',
#  'get_blocked_ids',
#  'get_blocks',
#  'get_direct_message',
#  'get_direct_messages',
#  'get_favorites',
#  'get_follower_ids',
#  'get_followers',
#  'get_friend_ids',
#  'get_friends',
#  'get_friendship',
#  'get_list',
#  'get_list_member',
#  'get_list_members',
#  'get_list_memberships',
#  'get_list_ownerships',
#  'get_list_subscriber',
#  'get_list_subscribers',
#  'get_list_subscriptions',
#  'get_lists',
#  'get_media_upload_status',
#  'get_muted_ids',
#  'get_mutes',
#  'get_oembed',
#  'get_place_trends',
#  'get_profile_banner',
#  'get_retweeter_ids',
#  'get_retweets',
#  'get_retweets_of_me',
#  'get_saved_search',
#  'get_saved_searches',
#  'get_settings',
#  'get_status',
#  'get_user',
#  'home_timeline',
#  'host',
#  'incoming_friendships',
#  'indicate_direct_message_typing',
#  'last_response',
#  'list_timeline',
#  'lookup_friendships',
#  'lookup_statuses',
#  'lookup_users',
#  'mark_direct_message_read',
#  'media_upload',
#  'mentions_timeline',
#  'no_retweets_friendships',
#  'outgoing_friendships',
#  'parser',
#  'proxy',
#  'rate_limit_status',
#  'remove_list_member',
#  'remove_list_members',
#  'remove_profile_banner',
#  'report_spam',
#  'request',
#  'retry_count',
#  'retry_delay',
#  'retry_errors',
#  'retweet',
#  'reverse_geocode',
#  'search_30_day',
#  'search_full_archive',
#  'search_geo',
#  'search_tweets',
#  'search_users',
#  'send_direct_message',
#  'session',
#  'set_settings',
#  'simple_upload',
#  'subscribe_list',
#  'supported_languages',
#  'timeout',
#  'unretweet',
#  'unsubscribe_list',
#  'update_friendship',
#  'update_list',
#  'update_profile',
#  'update_profile_banner',
#  'update_profile_image',
#  'update_status',
#  'update_status_with_media',
#  'upload_host',
#  'user_agent',
#  'user_timeline',
#  'verify_credentials',
#  'wait_on_rate_limit']

# %%
my_timeline = api.home_timeline()

# %%
import json

columns = set()
allowed_types = [int, str]
tweets_data = []
# columns.add('Tweeter')
for status in my_timeline:
#     print(dict(vars(status)), "\n \n")
    status_dict = dict(vars(status))
#     print(vars(status).keys(), "\n \n")
    print(status.user.screen_name)
    keys = status_dict.keys()
    single_tweet_data = {}
    for k in keys:
        if type(status_dict[k]) in allowed_types:
            columns.add(k)
            

header_cols = list(columns)
header_cols = ['tweeter', 'author'] + header_cols
for status in my_timeline:
    status_dict = dict(vars(status))
    single_tweet_data = {'tweeter': status.user.id, 'author': status.author.screen_name}
#     single_tweet_data['Tweeter'] = status.user.screen_name
    for h in header_cols[2::]:
        try:
            single_tweet_data[h] = status_dict[h]
        except:
            single_tweet_data[h] = "NaN"
#     print(single_tweet_data)
    tweets_data.append(single_tweet_data)

tweets_data_list = [[j for j in x.values()] for x in tweets_data]
# Out:
# Enibola1
# ManCityzenscom
# yinkakun
# kot_that
# ___Faye
# thebarakah_
# Nafeeeeeeees
# thefaiidat
# WholesomeMeme
# xtiah_o
# Dayex15
# Premauj
# justcruise4
# thebarakah_
# Ddoaaelsa
# SuperSportTV
# mide_kiki
# yaseerr___
# TheTimslicky
# TheTimslicky

# %%
print(header_cols, "\n")
print(tweets_data_list)
# print(tweets_data_list)
# Out:
# ['tweeter', 'author', 'lang', 'retweet_count', 'id_str', 'id', 'source', 'favorite_count', 'source_url', 'text']
#
# [[1293987206181408771, 'Enibola1', 'qme', 0, '1567107850723262469', 1567107850723262469, 'Twitter for Android', 0, 'http://twitter.com/download/android', '#NewProfilePic https://t.co/kR3FxuLlUm'], [1057248790200094725, 'ManCityzenscom', 'en', 0, '1567107647597383682', 1567107647597383682, 'ManCityzens.com', 1, 'https://www.mancityzens.com', "The world's 25 most expensive squads revealed in study. Where do City rank? 👇\nhttps://t.co/iaMoaIGn9k"], [814189493867540481, 'yinkakun', 'en', 0, '1567107268004528128', 1567107268004528128, 'Twitter for iPhone', 0, 'http://twitter.com/download/iphone', 'i have never ever felt more humiliated https://t.co/3hzQlvv6h6'], [1023294013, 'kot_that', 'zxx', 63, '1567107240687017987', 1567107240687017987, 'Twitter for iPhone', 0, 'http://twitter.com/download/iphone', 'RT @designbuddyorg: https://t.co/Ku5vz4VNYg'], [1088726825277247488, '___Faye', 'en', 1, '1567107229702148098', 1567107229702148098, 'Twitter for iPhone', 0, 'http://twitter.com/download/iphone', 'Wait, that 9ja born lady didn’t win the UK pm thing?'], [2883751252, 'thebarakah_', 'en', 316, '1567107107090059264', 1567107107090059264, 'Twitter for iPhone', 0, 'http://twitter.com/download/iphone', 'RT @OfficialOsas: It was such fun times hosting the #15thHeadies - Thanks for having me 💛 https://t.co/TheE7dUYaV'], [1265987850861977604, 'Nafeeeeeeees', 'en', 2832, '1567106927888400384', 1567106927888400384, 'Twitter for Android', 0, 'http://twitter.com/download/android', 'RT @themyiaaj: when I start my family we’re celebrating every holiday and doing it big. I just feel like ppl don’t do that anymore'], [1030825303587872768, 'thefaiidat', 'und', 2, '1567106843410931714', 1567106843410931714, 'Twitter for iPhone', 11, 'http://twitter.com/download/iphone', '+1 https://t.co/3C2zcjHTPF'], [762799939395158016, 'WholesomeMeme', 'zxx', 84, '1567106563667525634', 1567106563667525634, 'Twitter for Android', 636, 'http://twitter.com/download/android', 'https://t.co/sVcLiM6syb'], [815136566565892096, 'xtiah_o', 'en', 2, '1567106433384124421', 1567106433384124421, 'Twitter for iPhone', 0, 'http://twitter.com/download/iphone', 'RT @OGMangaHunter: Like please https://t.co/Lv49OllwGS'], [1287425724568211456, 'Dayex15', 'en', 387, '1567106404963553280', 1567106404963553280, 'Twitter for iPhone', 0, 'http://twitter.com/download/iphone', 'RT @Mbahdeyforyou: Two independent women dey fight for man 😂'], [1097892885314392064, 'Premauj', 'en', 184, '1567106312416133120', 1567106312416133120, 'Twitter Web App', 0, 'https://mobile.twitter.com', 'RT @Ronke_kuss: Well, Its funny that you people are complaining about bottles meanwhile it was easy to abuse someone because she mentioned…'], [1263843298365579264, 'justcruise4', 'en', 120, '1567106279746801666', 1567106279746801666, 'Twitter for iPhone', 0, 'http://twitter.com/download/iphone', 'RT @FCBarcelona: Is winning the @ChampionsLeague a realistic objective for Barça this season?\n\nKounde: "Um, YES." 🔥 https://t.co/CZobIdZxl9'], [2883751252, 'thebarakah_', 'en', 1633, '1567105960065236998', 1567105960065236998, 'Twitter for iPhone', 0, 'http://twitter.com/download/iphone', 'RT @SAINtJHN: Just because we’re no longer friends doesn’t mean we have to be enemies.'], [1179217480151121922, 'Ddoaaelsa', 'ar', 1, '1567105731572252672', 1567105731572252672, 'Twitter for Android', 0, 'http://twitter.com/download/android', 'RT @EssamTobar: من كتر الجفاف العاطفي اللي بقي عند الناس اما يشوفوا راجل حاضن مراته عادي بيخلوه فعل اسطوري واما بنت ترفضهم بيقتلوها !'], [29930178, 'SuperSportTV', 'en', 2, '1567105418492518407', 1567105418492518407, 'Twitter for Advertisers', 11, 'https://twitter.com', 'All eyes will be on the KZN Derby as Royal AM and the new boys Richards Bay as they go head-to-head in one of two… https://t.co/3yoQXsog9Q'], [1053023556601372673, 'mide_kiki', 'en', 1, '1567104958813638657', 1567104958813638657, 'Twitter for Android', 3, 'http://twitter.com/download/android', "Having to listen to 'someone you like  ...

# %%
# print(tweets_data)
with open('timeline_data.csv', 'w', encoding='UTF8', newline='\n') as f:
    writer = csv.writer(f)
    writer.writerow(header_cols)
    writer.writerows(tweets_data_list)

# %%
df = pd.DataFrame(tweets_data, columns=header_cols)
df.head()
# Out:
#           tweeter          author lang  retweet_count               id_str  \
# 0        Enibola1        Enibola1  qme              0  1567107850723262469
# 1  ManCityzenscom  ManCityzenscom   en              0  1567107647597383682
# 2        yinkakun        yinkakun   en              0  1567107268004528128
# 3        kot_that        kot_that  zxx             63  1567107240687017987
# 4         ___Faye         ___Faye   en              1  1567107229702148098
#
#                     id               source  favorite_count  \
# 0  1567107850723262469  Twitter for Android               0
# 1  1567107647597383682      ManCityzens.com               1
# 2  1567107268004528128   Twitter for iPhone               0
# 3  1567107240687017987   Twitter for iPhone               0
# 4  1567107229702148098   Twitter for iPhone               0
#
#                             source_url  \
# 0  http://twitter.com/download/android
# 1          https://www.mancityzens.com
# 2   http://twitter.com/download/iphone
# 3   http://twitter.com/download/iphone
# 4   http://twitter.com/download/iphone
#
#                                                 text
# 0             #NewProfilePic https://t.co/kR3FxuLlUm
# 1  The world's 25 most expensive squads revealed ...
# 2  i have never ever felt more humiliated https:/...
# 3        RT @designbuddyorg: https://t.co/Ku5vz4VNYg
# 4  Wait, that 9ja born lady didn’t win the UK pm ...

# %%
def extract_timeline_as_df(timeline_list):
    columns = set()
    allowed_types = [int, str]
    tweets_data = []
    # columns.add('Tweeter')
    for status in timeline_list:
    #     print(dict(vars(status)), "\n \n")
        status_dict = dict(vars(status))
    #     print(vars(status).keys(), "\n \n")
#         print(status.user.screen_name)
        keys = status_dict.keys()
        single_tweet_data = {}
        for k in keys:
            if type(status_dict[k]) in allowed_types:
                columns.add(k)

    header_cols = list(columns)
    header_cols = ['tweeter', 'author'] + header_cols
    for status in timeline_list:
        status_dict = dict(vars(status))
        single_tweet_data = {'tweeter': status.user.id_str, 'author': status.author.screen_name}
    #     single_tweet_data['Tweeter'] = status.user.screen_name
        for h in header_cols[2::]:
            try:
                single_tweet_data[h] = status_dict[h]
            except:
                single_tweet_data[h] = "NaN"
    #     print(single_tweet_data)
        tweets_data.append(single_tweet_data)

    tweets_data_list = [[j for j in x.values()] for x in tweets_data]
    df = pd.DataFrame(tweets_data, columns=header_cols)
    return df

# %%
imanie = api.get_user(screen_name="imanie")
imanie_timeline = imanie.timeline()
df1 = extract_timeline_as_df(imanie_timeline)
df1.head()
# Out:
#      tweeter  author  in_reply_to_status_id lang  retweet_count  \
# 0  204132871  imanie           1.567083e+18   en              0
# 1  204132871  imanie                    NaN   en             21
# 2  204132871  imanie                    NaN  und              3
# 3  204132871  imanie                    NaN   en              1
# 4  204132871  imanie                    NaN   en             28
#
#   in_reply_to_user_id_str in_reply_to_status_id_str in_reply_to_screen_name  \
# 0      939363214726397952       1567083094322155520             ebengho_art
# 1                    None                      None                    None
# 2                    None                      None                    None
# 3                    None                      None                    None
# 4                    None                      None                    None
#
#   quoted_status_id_str               id_str  in_reply_to_user_id  \
# 0                  NaN  1567097689250070536         9.393632e+17
# 1                  NaN  1567095225893388293                  NaN
# 2                  NaN  1567094057934938113                  NaN
# 3  1566898221846241281  1567094024963489793                  NaN
# 4                  NaN  1567093750597296129                  NaN
#
#                     id              source     quoted_status_id  \
# 0  1567097689250070536  Twitter for iPhone                  NaN
# 1  1567095225893388293  Twitter for iPhone                  NaN
# 2  1567094057934938113  Twitter for iPhone                  NaN
# 3  1567094024963489793  Twitter for iPhone  1566898221846241281
# 4  1567093750597296129  Twitter for iPhone                  NaN
#
#    favorite_count                          source_url  \
# 0               0  http://twitter.com/download/iphone
# 1               0  http://twitter.com/download/iphone
# 2               0  http://twitter.com/download/iphone
# 3               0  http://twitter.com/download/iphone
# 4               0  http://twitter.com/download/iphone
#
#                                                 text
# 0                  @ebengho_art This is so good 🥹🥹🔥🔥
# 1  RT @ebengho_art: GM✨\nHave a lovely day🌈 https...
# 2  RT @freddiejacobart: Gm 🌸💗 https://t.co/sWEMrR...
# 3      Tw: jump scare video. https://t.co/izS2D29yt4
# 4  RT @bolusowoolu: Gm ✨ 2021 self portrait \n\nW...
